# %%
import pandas as pd
N_A=pd.read_csv("Nd.csv") 
N_A
# Out:
#          type   rating_category  Duration_Category  movie_age  \
# 0       Movie             Adult             Medium          5
# 1     TV Show             Adult  Series(X Seasons)          4
# 2     TV Show             Adult  Series(X Seasons)          4
# 3     TV Show             Adult  Series(X Seasons)          4
# 4     TV Show             Adult  Series(X Seasons)          4
# ...       ...               ...                ...        ...
# 8716    Movie             Adult               Epic         18
# 8717  TV Show   Family-friendly  Series(X Seasons)          7
# 8718    Movie             Adult             Medium         16
# 8719    Movie  Teen/Young Adult             Medium         19
# 8720    Movie  Teen/Young Adult               Long         10
#
#      country_category        Directors Title_Words               Content Age
# 0       United States  Other Directors   1-5 Words  New Releases (0-5 years)
# ...

# %%
                            #Distribution of Rating Category(Univariate Analysis)


import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.countplot(data=N_A, x='rating_category')
plt.title('Distribution of Rating Category')
plt.xticks(rotation=45)
plt.show()

# %%
                               #Distribution of Duration_Category(Univariate Analysis)

plt.figure(figsize=(10,6))
sns.countplot(data=N_A, x='Duration_Category')
plt.title('Distribution of Duration Category')
plt.xticks(rotation=45)
plt.show()

# %%
                                #Distribution of Types(Movies or Series)(Univariate Analysis)

plt.figure(figsize=(10,6))
sns.countplot(data=N_A, x='type')
plt.title('Distribution of types')
plt.xticks(rotation=45)
plt.show()

# %%
                                       #STACKED BAR PLOT (Bivariate Analysis)


country_rating = pd.crosstab(N_A['country_category'], N_A['rating_category'])
country_rating.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Rating Category by Country Category')
plt.xlabel('Country Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
                                         #STACKED BAR PLOT (Bivariate Analysis)

country_rating = pd.crosstab(N_A['movie_age'], N_A['rating_category'])
country_rating.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Rating Category by  movie_age')
plt.xlabel('Movie age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
                                         #STACKED BAR PLOT (Bivariate Analysis)

country_rating = pd.crosstab(N_A['Content Age'], N_A['rating_category'])
country_rating.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Rating Category by Content Age')
plt.xlabel('Content_Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
                               #SCATTER PLOT 



import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,6)) 
sns.scatterplot(data=N_A, x="movie_age", y="rating_category",hue="rating_category") 
plt.title("Scatter plot of Movie age and rating category") 
plt.show()

# %%
                                         #STACKED BAR PLOT (Bivariate Analysis)

country_rating = pd.crosstab(N_A['type'], N_A['rating_category'])
country_rating.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Rating Category by  type')
plt.xlabel('type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
                                        #HEATMAP(Correlation Analysis)

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

rating_country_crosstab = pd.crosstab(N_A['rating_category'], N_A['country_category'])

plt.figure(figsize=(10, 6))
sns.heatmap(rating_country_crosstab, annot=True, cmap='Blues', fmt='d', cbar=True)

plt.title("Heatmap of Rating Category vs Country Category")
plt.xlabel("Country Category")
plt.ylabel("Rating Category")
plt.show()

# %%
                                       #HEATMAP(Correlation Analysis)


import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

rating_country_crosstab = pd.crosstab(N_A['rating_category'], N_A['Title_Words'])

plt.figure(figsize=(10, 6))
sns.heatmap(rating_country_crosstab, annot=True, cmap='Blues', fmt='d', cbar=True)

plt.title("Heatmap of Rating Category vs Movie Title Words")
plt.xlabel("Title words Category")
plt.ylabel("Rating Category")
plt.show()

# %%
                                         #HEATMAP(Correlation Analysis)


import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

rating_country_crosstab = pd.crosstab(N_A['rating_category'], N_A['Duration_Category'])

plt.figure(figsize=(10, 6))
sns.heatmap(rating_country_crosstab, annot=True, cmap='Blues', fmt='d', cbar=True)

plt.title("Heatmap of Rating Category vs Duration Category")
plt.xlabel("Duration Category")
plt.ylabel("Rating Category")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder 

Categorical_columns=["type","rating_category","Duration_Category","country_category","Directors","Title_Words","Content Age"] 

le=LabelEncoder() 

for col in Categorical_columns:
    N_A[col]=le.fit_transform(N_A[col]) 

N_A.head()
# Out:
#    type  rating_category  Duration_Category  movie_age  country_category  \
# 0     0                0                  2          5                 5
# 1     1                0                  3          4                 2
# 2     1                0                  3          4                 2
# 3     1                0                  3          4                 2
# 4     1                0                  3          4                 0
#
#    Directors  Title_Words  Content Age
# 0          3            0            1
# 1          3            0            1
# 2          3            0            1
# 3          3            0            1
# 4          3            0            1

# %%
from sklearn.preprocessing import StandardScaler 

scaler=StandardScaler() 

N_A["movie_age"]=scaler.fit_transform(N_A["movie_age"].values.reshape(-1, 1)) 

N_A.head()
# Out:
#    type  rating_category  Duration_Category  movie_age  country_category  \
# 0     0                0                  2  -0.658003                 5
# 1     1                0                  3  -0.771753                 2
# 2     1                0                  3  -0.771753                 2
# 3     1                0                  3  -0.771753                 2
# 4     1                0                  3  -0.771753                 0
#
#    Directors  Title_Words  Content Age
# 0          3            0            1
# 1          3            0            1
# 2          3            0            1
# 3          3            0            1
# 4          3            0            1

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split

X=N_A.drop(columns=["rating_category"]) 
y=N_A["rating_category"]  

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42) 

imp_rf=RandomForestClassifier(n_estimators=200,random_state=42) 

imp_rf.fit(X_train,y_train)

importances=imp_rf.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)


feature_importance_df
# Out:
#              Feature  Importance
# 2          movie_age    0.489241
# 3   country_category    0.202611
# 1  Duration_Category    0.167911
# 6        Content Age    0.048186
# 5        Title_Words    0.036843
# 0               type    0.028634
# 4          Directors    0.026573

# %%
from this above,

It is concluded that movie_age, country_category, Duration_category, Content_Age, Title_words are top 5 features 

that make huge influence on rating category(target) for audiences.....
